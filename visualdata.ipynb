# %%
import numpy as np
from JiweiCommonUtil.imgshow import showLineImg
valLabel = np.load('./val_density_out/p20_0179_7.npy')

print(valLabel.shape)

showLineImg([valLabel[0],valLabel[1],valLabel[2]])
# Out:
# (3, 80, 80)
